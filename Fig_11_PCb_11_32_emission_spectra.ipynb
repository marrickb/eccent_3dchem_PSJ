# %% [markdown]
# # Plotting the synthetic emission spectra generated with PSG for the spectral range of the Large Interferometer For Exoplanets. Absorption/emission features of important chemical species are indicated. Included as Figure 11 of the paper.
# ## Note: change to your own directories. PSG spectra files available in folder <i>emission_spectra_psg</i>

# %%
import warnings
import numpy as np
import iris.quickplot as qplt
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from matplotlib.patches import ConnectionPatch

# %%
warnings.filterwarnings("ignore")

# %%
### PROXIMA CEN B

pcb_0=pd.read_csv('../../eccent/PSG/GlobES/spectra/spectra0224/pcb_11_phase102.txt', skiprows=15,nrows=245, delim_whitespace=True,
                   names=['wave', 'total', 'stellar', 'planet'])
pcb_0['wave'] = pcb_0['wave'].astype('float')
pcb_1=pd.read_csv('../../eccent/PSG/GlobES/spectra/spectra0224/pcb_11_phase135.txt', skiprows=15,nrows=245, delim_whitespace=True,
                   names=['wave', 'total', 'stellar', 'planet'])
pcb_2=pd.read_csv('../../eccent/PSG/GlobES/spectra/spectra0224/pcb_11_phase167.txt', skiprows=15,nrows=245, delim_whitespace=True,
                   names=['wave', 'total', 'stellar', 'planet'])
pcb_3=pd.read_csv('../../eccent/PSG/GlobES/spectra/spectra0224/pcb_11_phase199.txt', skiprows=15,nrows=245, delim_whitespace=True,
                   names=['wave', 'total', 'stellar', 'planet'])
pcb_4=pd.read_csv('../../eccent/PSG/GlobES/spectra/spectra0224/pcb_11_phase231.txt', skiprows=15,nrows=245, delim_whitespace=True,
                   names=['wave', 'total', 'stellar', 'planet'])
pcb_5=pd.read_csv('../../eccent/PSG/GlobES/spectra/spectra0224/pcb_11_phase263.txt', skiprows=15,nrows=245, delim_whitespace=True,
                   names=['wave', 'total', 'stellar', 'planet'])
pcb_6=pd.read_csv('../../eccent/PSG/GlobES/spectra/spectra0224/pcb_11_phase296.txt', skiprows=15,nrows=245, delim_whitespace=True,
                   names=['wave', 'total', 'stellar', 'planet'])
pcb_7=pd.read_csv('../../eccent/PSG/GlobES/spectra/spectra0224/pcb_11_phase328.txt', skiprows=16,nrows=245, delim_whitespace=True,
                   names=['wave', 'total', 'stellar', 'planet'])
pcb_8=pd.read_csv('../../eccent/PSG/GlobES/spectra/spectra0224/pcb_11_phase0.txt', skiprows=16,nrows=245, delim_whitespace=True,
                   names=['wave', 'total', 'stellar', 'planet'])
pcb_9=pd.read_csv('../../eccent/PSG/GlobES/spectra/spectra0224/pcb_11_phase32.txt', skiprows=16,nrows=245, delim_whitespace=True,
                   names=['wave', 'total', 'stellar', 'planet'])
pcb_10=pd.read_csv('../../eccent/PSG/GlobES/spectra/spectra0224/pcb_11_phase64.txt', skiprows=15,nrows=245, delim_whitespace=True,
                   names=['wave', 'total', 'stellar', 'planet'])
pcb_11=pd.read_csv('../../eccent/PSG/GlobES/spectra/spectra0224/pcb_11_phase96.txt', skiprows=15,nrows=245, delim_whitespace=True,
                   names=['wave', 'total', 'stellar', 'planet'])

# %%
colors = plt.cm.tab20(np.linspace(0, 1, 13))
fig, ax = plt.subplots(figsize=(12,5))
ax.axvspan(5.2, 8, color='grey', alpha=0.15)
ax.text(6.6, 72, 'H$_2$O', color='black', fontsize=18, ha='center', va='bottom')
ax.axvspan(5.6, 7.2, 0, 0.85, color='grey', alpha=0.15)
ax.text(6.4, 60, 'O$_2$-O$_2$', color='black', fontsize=18, ha='center', va='bottom')
ax.text(6.4, 55, 'O$_2$-N$_2$', color='black', fontsize=18, ha='center', va='bottom')

ax.axvspan(9.4, 9.8, color='grey', alpha=0.15)
ax.text(9.6, 72, 'O$_3$', color='black', fontsize=18, ha='center', va='bottom')

ax.axvspan(12.5, 12.7, color='grey', alpha=0.15)
ax.text(12.6, 32, 'CO$_2$', color='black', fontsize=18, ha='center', va='bottom')

ax.axvspan(14, 16.25, color='grey', alpha=0.15)
ax.text(15.125, 72, 'CO$_2$', color='black', fontsize=18, ha='center', va='bottom')

ax.axvspan(16.3, 18.5, color='grey', alpha=0.15)
ax.text(17.4, 72, 'H$_2$O', color='black', fontsize=18, ha='center', va='bottom')

ax.text(-0.09,1.05, '(a)', size=18, weight='bold',transform=ax.transAxes)
fig.suptitle('Proxima Centauri b ${-}$ 1:1 spin-orbit resonance', fontsize=22,y=0.95)
ax.plot(pcb_0['wave'], 1e6*pcb_0['planet']/pcb_0['stellar'],label='103$^\circ$', c=colors[0])
ax.plot(pcb_1['wave'], 1e6*pcb_1['planet']/pcb_1['stellar'],label='135$^\circ$', c=colors[1])
ax.plot(pcb_2['wave'], 1e6*pcb_2['planet']/pcb_2['stellar'],label='167$^\circ$', c=colors[2])
ax.plot(pcb_3['wave'], 1e6*pcb_3['planet']/pcb_3['stellar'],label='200$^\circ$', c=colors[3])
ax.plot(pcb_4['wave'], 1e6*pcb_4['planet']/pcb_4['stellar'],label='232$^\circ$', c=colors[4])
ax.plot(pcb_5['wave'], 1e6*pcb_5['planet']/pcb_5['stellar'],label='264$^\circ$', c=colors[5])
ax.plot(pcb_6['wave'], 1e6*pcb_6['planet']/pcb_6['stellar'],label='296$^\circ$', c=colors[6])
ax.plot(pcb_7['wave'], 1e6*pcb_7['planet']/pcb_7['stellar'],label='328$^\circ$', c=colors[7])
ax.plot(pcb_8['wave'], 1e6*pcb_8['planet']/pcb_8['stellar'],label='0$^\circ$', c=colors[8])

ax.plot(pcb_9['wave'], 1e6*pcb_9['planet']/pcb_9['stellar'],label='32$^\circ$', c=colors[12])
ax.plot(pcb_10['wave'],1e6*pcb_10['planet']/pcb_10['stellar'],label='65$^\circ$', c=colors[10])
ax.plot(pcb_11['wave'], 1e6*pcb_11['planet']/pcb_11['stellar'],label='97$^\circ$', c=colors[11])

ax.set_xlabel('Wavelength($\mu$m)', size=20)
ax.set_ylabel('Contrast (ppm)', size=20)
ax.tick_params(axis='both', which='major', labelsize=18)
#ax.set_yscale('log')
# Set the initial limits for the plot
initial_xlim = ax.get_xlim()  # Get the current x-axis limits
initial_ylim = ax.get_ylim()  # Get the current y-axis limits

# Define the zoomed region
zoom_xlim = (9.15, 10.1)  # Set the desired x-axis limits for zooming
zoom_ylim = (1, 10)  # Set the desired y-axis limits for zooming

# Perform the zoom by updating the plot limits
ax.set_xlim(4,18.5)
ax.set_ylim(0,80)#0,27

# Create the inset plot for the zoomed region
inset_ax = inset_axes(ax, width="35%", height="35%", loc='upper left',
                     bbox_to_anchor=(0.04,-0.35,1,1), bbox_transform=ax.transAxes)

inset_ax.axvspan(9.4, 9.8, color='grey', alpha=0.15)
inset_ax.text(9.6, 7, 'O$_3$', color='black', fontsize=18, ha='center', va='bottom')

inset_ax.plot(pcb_0['wave'], 1e6*pcb_0['planet']/pcb_0['stellar'],label='103$^\circ$', c=colors[0])
inset_ax.plot(pcb_1['wave'], pcb_1['planet']/pcb_1['stellar'],label='135$^\circ$', c=colors[1])
inset_ax.plot(pcb_2['wave'], 1e6*pcb_2['planet']/pcb_2['stellar'],label='167$^\circ$', c=colors[2])
inset_ax.plot(pcb_3['wave'], 1e6*pcb_3['planet']/pcb_3['stellar'],label='200$^\circ$', c=colors[3])
inset_ax.plot(pcb_4['wave'], 1e6*pcb_4['planet']/pcb_4['stellar'],label='232$^\circ$', c=colors[4])
inset_ax.plot(pcb_5['wave'], 1e6*pcb_5['planet']/pcb_5['stellar'],label='264$^\circ$', c=colors[5])
inset_ax.plot(pcb_6['wave'], 1e6*pcb_6['planet']/pcb_6['stellar'],label='296$^\circ$', c=colors[6])
inset_ax.plot(pcb_7['wave'], 1e6*pcb_7['planet']/pcb_7['stellar'],label='328$^\circ$', c=colors[7])
inset_ax.plot(pcb_8['wave'], 1e6*pcb_8['planet']/pcb_8['stellar'],label='0$^\circ$', c=colors[8])
inset_ax.plot(pcb_9['wave'], 1e6*pcb_9['planet']/pcb_9['stellar'],label='32$^\circ$', c=colors[12])
inset_ax.plot(pcb_10['wave'], 1e6*pcb_10['planet']/pcb_10['stellar'],label='65$^\circ$', c=colors[10])
inset_ax.plot(pcb_11['wave'], 1e6*pcb_11['planet']/pcb_11['stellar'],label='97$^\circ$', c=colors[11])

inset_ax.set_xlim(zoom_xlim)
inset_ax.set_ylim(zoom_ylim)
inset_ax.tick_params(axis='both', which='major', labelsize=15)

# Draw a box around the zoomed region in the larger plot
zoom_box = plt.Rectangle((zoom_xlim[0], zoom_ylim[0]), zoom_xlim[1] - zoom_xlim[0], zoom_ylim[1] - zoom_ylim[0],
                         facecolor='none', edgecolor='black', linewidth=1.5, linestyle='--')
ax.add_patch(zoom_box)

 # Add lines connecting the zoom box to the inset plot
line_kwargs = {'color': 'black', 'linewidth': 1.0, 'linestyle': '--'}
line1 = ConnectionPatch(xyA=(zoom_xlim[0], zoom_ylim[0]), xyB=(zoom_xlim[0], zoom_ylim[0]),
                        coordsA='data', coordsB='data', axesA=ax, axesB=inset_ax, **line_kwargs)
line2 = ConnectionPatch(xyA=(zoom_xlim[0], zoom_ylim[1]), xyB=(zoom_xlim[0], zoom_ylim[1]),
                        coordsA='data', coordsB='data', axesA=ax, axesB=inset_ax, **line_kwargs)
line3 = ConnectionPatch(xyA=(zoom_xlim[1], zoom_ylim[1]), xyB=(zoom_xlim[1], zoom_ylim[1]),
                        coordsA='data', coordsB='data', axesA=ax, axesB=inset_ax, **line_kwargs)
line4 = ConnectionPatch(xyA=(zoom_xlim[1], zoom_ylim[0]), xyB=(zoom_xlim[1], zoom_ylim[0]),
                        coordsA='data', coordsB='data', axesA=ax, axesB=inset_ax, **line_kwargs)
ax.add_artist(line1)
#ax.add_artist(line2)
#ax.add_artist(line3)
ax.add_artist(line4)

ax.legend(loc='upper center', bbox_to_anchor=(0.548, 1), fontsize=14, ncol=2) #bbox_to_anchor=(0.85, 0.52)

#plt.savefig('PSG/GlobES/spectra/pcb_11_emission_4-18_2.pdf', bbox_inches='tight')
plt.show()

# %%
### PROXIMA CEN B
pcb_32_0=pd.read_csv('../../eccent/PSG/GlobES/spectra/spectra0224/pcb_32_fix_phase102.txt', skiprows=17,nrows=245, delim_whitespace=True,
                   names=['wave', 'total', 'stellar', 'planet'])
pcb_0['wave'] = pcb_0['wave'].astype('float')
pcb_32_1=pd.read_csv('../../eccent/PSG/GlobES/spectra/spectra0224/pcb_32_fix_phase135.txt', skiprows=17,nrows=245, delim_whitespace=True,
                   names=['wave', 'total', 'stellar', 'planet'])
pcb_32_2=pd.read_csv('../../eccent/PSG/GlobES/spectra/spectra0224/pcb_32_fix_phase167.txt', skiprows=17,nrows=245, delim_whitespace=True,
                   names=['wave', 'total', 'stellar', 'planet'])
pcb_32_3=pd.read_csv('../../eccent/PSG/GlobES/spectra/spectra0224/pcb_32_fix_phase199.txt', skiprows=17,nrows=245, delim_whitespace=True,
                   names=['wave', 'total', 'stellar', 'planet'])
pcb_32_4=pd.read_csv('../../eccent/PSG/GlobES/spectra/spectra0224/pcb_32_fix_phase231.txt', skiprows=17,nrows=245, delim_whitespace=True,
                   names=['wave', 'total', 'stellar', 'planet'])
pcb_32_5=pd.read_csv('../../eccent/PSG/GlobES/spectra/spectra0224/pcb_32_fix_phase263.txt', skiprows=17,nrows=245, delim_whitespace=True,
                   names=['wave', 'total', 'stellar', 'planet'])
pcb_32_6=pd.read_csv('../../eccent/PSG/GlobES/spectra/spectra0224/pcb_32_fix_phase296.txt', skiprows=18,nrows=245, delim_whitespace=True,
                  names=['wave', 'total', 'stellar', 'planet'])
pcb_32_7=pd.read_csv('../../eccent/PSG/GlobES/spectra/spectra0224/pcb_32_fix_phase328.txt', skiprows=18,nrows=245, delim_whitespace=True,
                  names=['wave', 'total', 'stellar', 'planet'])
pcb_32_8=pd.read_csv('../../eccent/PSG/GlobES/spectra/spectra0224/pcb_32_fix_phase0.txt', skiprows=18,nrows=245, delim_whitespace=True,
                  names=['wave', 'total', 'stellar', 'planet'])
pcb_32_9=pd.read_csv('../../eccent/PSG/GlobES/spectra/spectra0224/pcb_32_fix_phase32.txt', skiprows=18,nrows=245, delim_whitespace=True,
                  names=['wave', 'total', 'stellar', 'planet'])
pcb_32_10=pd.read_csv('../../eccent/PSG/GlobES/spectra/spectra0224/pcb_32_fix_phase64.txt', skiprows=17,nrows=245, delim_whitespace=True,
                  names=['wave', 'total', 'stellar', 'planet'])
pcb_32_11=pd.read_csv('../../eccent/PSG/GlobES/spectra/spectra0224/pcb_32_fix_phase96.txt', skiprows=17,nrows=245, delim_whitespace=True,
                  names=['wave', 'total', 'stellar', 'planet'])
pcb_32_12=pd.read_csv('../../eccent/PSG/GlobES/spectra/spectra0224/pcb_32_fix_phase129.txt', skiprows=17,nrows=245, delim_whitespace=True,
                  names=['wave', 'total', 'stellar', 'planet'])

# %%
colors = plt.cm.tab20(np.linspace(0, 1, 13))

fig, ax = plt.subplots(figsize=(12,5))
ax.text(-0.09,1.05, '(b)', size=18, weight='bold',transform=ax.transAxes)
fig.suptitle('Proxima Centauri b ${-}$ 3:2 spin-orbit resonance', fontsize=22,y=0.95)

ax.axvspan(5.2, 8, color='grey', alpha=0.15)
ax.text(6.6, 72, 'H$_2$O', color='black', fontsize=18, ha='center', va='bottom')
ax.axvspan(5.6, 7.2, 0, 0.85, color='grey', alpha=0.15)
ax.text(6.4, 60, 'O$_2$-O$_2$', color='black', fontsize=18, ha='center', va='bottom')
ax.text(6.4, 55, 'O$_2$-N$_2$', color='black', fontsize=18, ha='center', va='bottom')

ax.axvspan(9.4, 9.8, color='grey', alpha=0.15)
ax.text(9.6, 72, 'O$_3$', color='black', fontsize=18, ha='center', va='bottom')

ax.axvspan(12.5, 12.7, color='grey', alpha=0.15)
ax.text(12.6, 32, 'CO$_2$', color='black', fontsize=18, ha='center', va='bottom')

ax.axvspan(14, 16.25, color='grey', alpha=0.15)
ax.text(15.125, 72, 'CO$_2$', color='black', fontsize=18, ha='center', va='bottom')

ax.axvspan(16.3, 18.5, color='grey', alpha=0.15)
ax.text(17.4, 72, 'H$_2$O', color='black', fontsize=18, ha='center', va='bottom')

ax.plot(pcb_32_0['wave'], 1e6*pcb_32_0['planet']/pcb_32_0['stellar'],label='103$^\circ$', c=colors[0])
ax.plot(pcb_32_1['wave'], 1e6*pcb_32_1['planet']/pcb_32_1['stellar'],label='135$^\circ$', c=colors[1])
ax.plot(pcb_32_2['wave'], 1e6*pcb_32_2['planet']/pcb_32_2['stellar'],label='167$^\circ$', c=colors[2])
ax.plot(pcb_32_3['wave'], 1e6*pcb_32_3['planet']/pcb_32_3['stellar'],label='200$^\circ$', c=colors[3])
ax.plot(pcb_32_4['wave'], 1e6*pcb_32_4['planet']/pcb_32_4['stellar'],label='232$^\circ$', c=colors[4])
ax.plot(pcb_32_5['wave'], 1e6*pcb_32_5['planet']/pcb_32_5['stellar'],label='264$^\circ$', c=colors[5])
ax.plot(pcb_32_6['wave'], 1e6*pcb_32_6['planet']/pcb_32_6['stellar'],label='296$^\circ$', c=colors[6])
ax.plot(pcb_32_7['wave'], 1e6*pcb_32_7['planet']/pcb_32_7['stellar'],label='328$^\circ$', c=colors[7])
ax.plot(pcb_32_8['wave'], 1e6*pcb_32_8['planet']/pcb_32_8['stellar'],label='0$^\circ$', c=colors[8])
ax.plot(pcb_32_9['wave'], 1e6*pcb_32_9['planet']/pcb_32_9['stellar'],label='32$^\circ$', c=colors[12])
ax.plot(pcb_32_10['wave'], 1e6*pcb_32_10['planet']/pcb_32_10['stellar'],label='65$^\circ$', c=colors[10])
ax.plot(pcb_32_11['wave'], 1e6*pcb_32_11['planet']/pcb_32_11['stellar'],label='97$^\circ$', c=colors[11])
# ax.plot(pcb_32_12['wave'], 1e6*pcb_32_12['planet']/pcb_32_12['stellar'],label='129$^\circ$', ls='--', c=colors[0])
# ax.plot(pcb_32_13['wave'], 1e6*pcb_32_13['planet']/pcb_32_13['stellar'],label='135$^\circ$', ls='--', c=colors[1])
# ax.plot(pcb_32_14['wave'], 1e6*pcb_32_14['planet']/pcb_32_14['stellar'],label='167$^\circ$', ls='--', c=colors[2])
# ax.plot(pcb_32_15['wave'], 1e6*pcb_32_15['planet']/pcb_32_15['stellar'],label='200$^\circ$', ls='--', c=colors[3])
# ax.plot(pcb_32_16['wave'], 1e6*pcb_32_16['planet']/pcb_32_16['stellar'],label='232$^\circ$', ls='--', c=colors[4])
# ax.plot(pcb_32_17['wave'], 1e6*pcb_32_17['planet']/pcb_32_17['stellar'],label='264$^\circ$', ls='--', c=colors[5])
# ax.plot(pcb_32_18['wave'], 1e6*pcb_32_18['planet']/pcb_32_18['stellar'],label='296$^\circ$', ls='--', c=colors[6])
# ax.plot(pcb_32_19['wave'], 1e6*pcb_32_19['planet']/pcb_32_19['stellar'],label='328$^\circ$', ls='--', c=colors[7])
# ax.plot(pcb_32_20['wave'], 1e6*pcb_32_20['planet']/pcb_32_20['stellar'],label='0$^\circ$', ls='--', c=colors[8])
# ax.plot(pcb_32_21['wave'], 1e6*pcb_32_21['planet']/pcb_32_21['stellar'],label='32$^\circ$', ls='--', c=colors[9])
# ax.plot(pcb_32_22['wave'], 1e6*pcb_32_22['planet']/pcb_32_22['stellar'],label='65$^\circ$', ls='--', c=colors[10])#ax.plot(pcb_32_50['wave'], pcb_32_50['total'],label='t$_{50}$', c=colors[13])
# #ax.plot(pcb_32_114['wave'], pcb_32_114['total'],label='t$_{114}$', c=colors[14])



ax.legend(loc='upper center', bbox_to_anchor=(0.548, 1), fontsize=14, ncol=2) #bbox_to_anchor=(0.85, 0.52)
ax.set_xlabel('Wavelength($\mu$m)', size=20)
ax.set_ylabel('Contrast (ppm)', size=20)
ax.tick_params(axis='both', which='major', labelsize=18)
#ax.set_yscale('log')
# Set the initial limits for the plot
initial_xlim = ax.get_xlim()  # Get the current x-axis limits
initial_ylim = ax.get_ylim()  # Get the current y-axis limits

# Define the zoomed region
zoom_xlim = (9.15, 10.1)  # Set the desired x-axis limits for zooming
zoom_ylim = (1, 10)  # Set the desired y-axis limits for zooming

# Perform the zoom by updating the plot limits
ax.set_xlim(4,18.5)
ax.set_ylim(0,80)#0,27

# Create the inset plot for the zoomed region
inset_ax = inset_axes(ax, width="35%", height="35%", loc='upper left',
                     bbox_to_anchor=(0.04,-0.35,1,1), bbox_transform=ax.transAxes)

inset_ax.axvspan(9.4, 9.8, color='grey', alpha=0.15)
inset_ax.text(9.6, 8, 'O$_3$', color='black', fontsize=18, ha='center', va='bottom')

inset_ax.plot(pcb_32_0['wave'], 1e6*pcb_32_0['planet']/pcb_32_0['stellar'],label='103$^\circ$', c=colors[0])
inset_ax.plot(pcb_32_1['wave'], 1e6*pcb_32_1['planet']/pcb_32_1['stellar'],label='135$^\circ$', c=colors[1])
inset_ax.plot(pcb_32_2['wave'], 1e6*pcb_32_2['planet']/pcb_32_2['stellar'],label='167$^\circ$', c=colors[2])
inset_ax.plot(pcb_32_3['wave'], 1e6*pcb_32_3['planet']/pcb_32_3['stellar'],label='200$^\circ$', c=colors[3])
inset_ax.plot(pcb_32_4['wave'], 1e6*pcb_32_4['planet']/pcb_32_4['stellar'],label='232$^\circ$', c=colors[4])
inset_ax.plot(pcb_32_5['wave'], 1e6*pcb_32_5['planet']/pcb_32_5['stellar'],label='264$^\circ$', c=colors[5])
inset_ax.plot(pcb_32_6['wave'], 1e6*pcb_32_6['planet']/pcb_32_6['stellar'],label='296$^\circ$', c=colors[6])
inset_ax.plot(pcb_32_7['wave'], 1e6*pcb_32_7['planet']/pcb_32_7['stellar'],label='328$^\circ$', c=colors[7])
inset_ax.plot(pcb_32_8['wave'], 1e6*pcb_32_8['planet']/pcb_32_8['stellar'],label='0$^\circ$', c=colors[8])
inset_ax.plot(pcb_32_9['wave'], 1e6*pcb_32_9['planet']/pcb_32_9['stellar'],label='32$^\circ$', c=colors[12])
inset_ax.plot(pcb_32_10['wave'], 1e6*pcb_32_10['planet']/pcb_32_10['stellar'],label='65$^\circ$', c=colors[10])
inset_ax.plot(pcb_32_11['wave'], 1e6*pcb_32_11['planet']/pcb_32_11['stellar'],label='97$^\circ$', c=colors[11])
inset_ax.plot(pcb_32_12['wave'], 1e6*pcb_32_12['planet']/pcb_32_12['stellar'],label='129$^\circ$', c=colors[12])
inset_ax.set_xlim(zoom_xlim)
inset_ax.set_ylim(zoom_ylim)
#inset_ax.set_title('Zoomed In')
inset_ax.tick_params(axis='both', which='major', labelsize=15)

# Draw a box around the zoomed region in the larger plot
zoom_box = plt.Rectangle((zoom_xlim[0], zoom_ylim[0]), zoom_xlim[1] - zoom_xlim[0], zoom_ylim[1] - zoom_ylim[0],
                         facecolor='none', edgecolor='black', linewidth=1.5, linestyle='--')
ax.add_patch(zoom_box)

 # Add lines connecting the zoom box to the inset plot
line_kwargs = {'color': 'black', 'linewidth': 1.0, 'linestyle': '--'}
line1 = ConnectionPatch(xyA=(zoom_xlim[0], zoom_ylim[0]), xyB=(zoom_xlim[0], zoom_ylim[0]),
                        coordsA='data', coordsB='data', axesA=ax, axesB=inset_ax, **line_kwargs)
line2 = ConnectionPatch(xyA=(zoom_xlim[0], zoom_ylim[1]), xyB=(zoom_xlim[0], zoom_ylim[1]),
                        coordsA='data', coordsB='data', axesA=ax, axesB=inset_ax, **line_kwargs)
line3 = ConnectionPatch(xyA=(zoom_xlim[1], zoom_ylim[1]), xyB=(zoom_xlim[1], zoom_ylim[1]),
                        coordsA='data', coordsB='data', axesA=ax, axesB=inset_ax, **line_kwargs)
line4 = ConnectionPatch(xyA=(zoom_xlim[1], zoom_ylim[0]), xyB=(zoom_xlim[1], zoom_ylim[0]),
                        coordsA='data', coordsB='data', axesA=ax, axesB=inset_ax, **line_kwargs)
ax.add_artist(line1)
#ax.add_artist(line2)
#ax.add_artist(line3)
ax.add_artist(line4)

#plt.savefig('../../eccent/PSG/GlobES/spectra/pcb_32_fix_emission_4-18_2.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# # Some statistics on differences and peak wavelengths

# %%
def peak_lambda(dataframe):
    idmax=dataframe['planet'].idxmax()
    print(dataframe['wave'][idmax])
peak_lambda(pcb_8)
peak_lambda(pcb_3)
peak_lambda(pcb_32_9)
peak_lambda(pcb_32_3)

#plot differences between max and miimum contrasts for 1:1 case
plt.plot(pcb_2['wave'][:222], (1e6*pcb_9['planet']/pcb_9['stellar']-1e6*pcb_2['planet']/pcb_2['stellar'])[:222])
plt.show()
print(max((1e6*pcb_9['planet']/pcb_9['stellar']-1e6*pcb_2['planet']/pcb_2['stellar'])[:222]))
# Out:
# 35.45124727680124

# %%
#plot differences between max cases 3:2 res versus 1:1
plt.plot(pcb_2['wave'][:222], (1e6*pcb_32_9['planet']/pcb_32_9['stellar']-1e6*pcb_9['planet']/pcb_9['stellar'])[:222])
plt.show()
print(max((1e6*pcb_32_9['planet']/pcb_32_9['stellar']-1e6*pcb_9['planet']/pcb_9['stellar'])))
# Out:
# 2.222855761470317
